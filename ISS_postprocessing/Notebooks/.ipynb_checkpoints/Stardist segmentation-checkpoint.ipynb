# %% [markdown]
# # Cell segmentation using Stardist

# %% [markdown]
# ## Import packages
# We import the necessary packages. `ISS_postprocessing` includes some modules requiring a functional and properly installed CUDA-compatible GPU. They will work but they will be considerably slower on CPU.

# %%
import ISS_postprocessing.segmentation as SEG

# %% [markdown]
# ## Cell segmentation using Stardist
#
# In this step we build a **segmentation mask** from the DAPI signal.
# For each region, the script searches for the stitched DAPI image in:
#
# `/preprocessing/Cycle1/3_stitched/Cycle1_ch4.tif`
#
# By default, channel **4** is used for DAPI. Update `DAPI_ch` if your data uses a different channel.
#
# Segmentation methods are implemented in `ISS_postprocessing.segmentation`.
# Both **StarDist** and **Cellpose** are available. Custom segmentation methods can also be used, but must be run outside this notebook.
#
# In this tutorial, segmentation is performed with **Stardist**. Have a look at the functions in `ISS_postprocessing.segmentation` for alternative strategies.
#
# ### Function parameters
#
# `input_dir` *(str)*: Path to the parent directory containing the preprocessed region folders (e.g. `/R1/`, `/R2/`, …). These folders are created automatically during preprocessing.
#
# `region` *(list of str)*: Identifiers of the regions to process.
#
# `DAPI_ch` *(int, default=4)*: Index of the DAPI channel (0-based).
#
# `model_name` *(str, default="2D_versatile_fluo")*: Name of the StarDist pre-trained model. Can be replaced with another pre-trained or custom model (see StarDist documentation).
#
# `expand_cells` *(bool, default=True)*: Whether to expand each segmented cell. Expansion helps capture peri- and extra-nuclear signal, but should be applied with care.
#
# `n_tiles` *(tuple of int, default=(4,4))*: Number of tiles to split the image into for faster processing.
#
# `expanded_distance` *(int, default=20)*: Expansion distance in pixels applied to each nucleus.

# %% [markdown]
# > **Note:**
# > You need to specify the names of the regions you want to post-process.
# > Multiple regions can be processed in one run, and they will all be analyzed using the same parameters.
# > In most cases this is fine, but there may be situations where individual regions need to be treated differently.

# %%
input_dir = '/path/to/regions/'
regions = ['R1', 'R2', 'R3']

# %%
input_dir =  '/mnt/DATA/ext_home/saga/test/saga/output_tif_autosaved/redlionfish/'
regions = ['R1']

# %%
for region in regions: 
    
    SEG.stardist_segmentation(
        input_dir,
        region,
        DAPI_ch=4, 
        model_name = '2D_versatile_fluo',
        expand_cells = True, 
        n_tiles = (4,4), 
        expanded_distance = 20,)
# Out:
# Processing region: R1
# DAPI image path: /mnt/DATA/ext_home/saga/test/saga/output_tif_autosaved/redlionfish/R1/preprocessing/Cycle1/3_stitched/Cycle1_ch4.tif
# Image shape: (2052, 3924)
# Normalizing image (1–99.8 percentile)…
# Initializing StarDist model: 2D_versatile_fluo
# Predicting instances (n_tiles=(4, 4))…
# Relabeling…
# Saving labels: /mnt/DATA/ext_home/saga/test/saga/output_tif_autosaved/redlionfish/R1/postprocessing/segmentation/R1_stardist_labels.npz
# Expanding labels by 20 px…
# Saving expanded labels (npz): /mnt/DATA/ext_home/saga/test/saga/output_tif_autosaved/redlionfish/R1/postprocessing/segmentation/R1_stardist_expanded.npz
# Processing complete.
